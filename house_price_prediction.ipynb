# %% [markdown]
# # House Price Prediction with CatBoost
#
# This notebook implements a machine learning model to predict house prices using the CatBoostRegressor algorithm.

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
from catboost import CatBoostRegressor

# %% [markdown]
# ## 2. Load Dataset

# %%
data = pd.read_csv("CSVs/house_prices.csv")

print(data.head())
print(data.shape)
print(data.info())

# %% [markdown]
# ## 3. Data Preprocessing

# %%
# Convert categorical column to numerical columns
data = pd.get_dummies(data, columns=["City"])

# Separate features and target
X = data.drop("Price", axis=1)
y = data["Price"]

# %% [markdown]
# ## 4. Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.1,
    random_state=42
)

# %% [markdown]
# ## 5. Create Model

# %%
model = CatBoostRegressor(
    save_snapshot=True,
    snapshot_file="Test_house_price",
    snapshot_interval=2,
    verbose=False
)

# %% [markdown]
# ## 6. Train Model

# %%
model.fit(X_train, y_train)

# %% [markdown]
# ## 7. Prediction

# %%
pred = model.predict(X_test)

# %% [markdown]
# ## 8. Model Evaluation

# %%
mae = mean_absolute_error(y_test, pred)
r2 = r2_score(y_test, pred)

print("MAE:", mae)
print("R² Score:", r2)
